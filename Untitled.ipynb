# %%
import torch
import numpy as np
from PIL import Image
import sys
np.set_printoptions(threshold=sys.maxsize)

# %%
smiley = torch.tensor(np.asarray(Image.open('imgs/drone.png').convert('RGBA'))).float()
print(smiley.shape)
print(smiley)
# Out:
# torch.Size([40, 40, 4])
# tensor([[[255., 255., 255., 255.],
#          [255., 255., 255., 255.],
#          [255., 255., 255., 255.],
#          ...,
#          [255., 255., 255., 255.],
#          [255., 255., 255., 255.],
#          [255., 255., 255., 255.]],
#
#         [[255., 255., 255., 255.],
#          [255., 255., 255., 255.],
#          [255., 255., 255., 255.],
#          ...,
#          [255., 255., 255., 255.],
#          [255., 255., 255., 255.],
#          [255., 255., 255., 255.]],
#
#         [[255., 255., 255., 255.],
#          [255., 255., 255., 255.],
#          [255., 255., 255., 255.],
#          ...,
#          [255., 255., 255., 255.],
#          [255., 255., 255., 255.],
#          [255., 255., 255., 255.]],
#
#         ...,
#
#         [[255., 255., 255., 255.],
#          [255., 255., 255., 255.],
#          [255., 255., 255., 255.],
#          ...,
#          [255., 255., 255., 255.],
#          [255., 255., 255., 255.],
# ...

# %%
print(smiley[35])
# Out:
# tensor([7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7.,
#         7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7., 7.,
#         7., 7., 7., 7.])

# %%
wing = torch.tensor(np.asarray(Image.open('imgs/wing_profile.png'))).float()
print(wing.shape)
print(wing[0])
# Out:
# torch.Size([30, 80, 4])
# tensor([[255., 255., 255., 255.],
#         [255., 255., 255., 255.],
#         [255., 255., 255., 255.],
#         [255., 255., 255., 255.],
#         [255., 255., 255., 255.],
#         [255., 255., 255., 255.],
#         [255., 255., 255., 255.],
#         [255., 255., 255., 255.],
#         [255., 255., 255., 255.],
#         [255., 255., 255., 255.],
#         [255., 255., 255., 255.],
#         [255., 255., 255., 255.],
#         [255., 255., 255., 255.],
#         [255., 255., 255., 255.],
#         [255., 255., 255., 255.],
#         [255., 255., 255., 255.],
#         [255., 255., 255., 255.],
#         [255., 255., 255., 255.],
#         [255., 255., 255., 255.],
#         [255., 255., 255., 255.],
#         [255., 255., 255., 255.],
#         [255., 255., 255., 255.],
#         [255., 255., 255., 255.],
#         [255., 255., 255., 255.],
#         [255., 255., 255., 255.],
#         [255., 255., 255., 255.],
#         [255., 255., 255., 255.],
# ...

# %%
smiley = Image.open('imgs/circle.png').convert('RGBA')
smiley = torch.tensor(np.asarray(smiley)).float()
print(smiley.shape)
print(smiley)
# Out:
# torch.Size([40, 40, 4])
# tensor([[[255., 255., 255., 255.],
#          [255., 255., 255., 255.],
#          [255., 255., 255., 255.],
#          ...,
#          [255., 255., 255., 255.],
#          [255., 255., 255., 255.],
#          [255., 255., 255., 255.]],
#
#         [[255., 255., 255., 255.],
#          [255., 255., 255., 255.],
#          [255., 255., 255., 255.],
#          ...,
#          [255., 255., 255., 255.],
#          [255., 255., 255., 255.],
#          [255., 255., 255., 255.]],
#
#         [[255., 255., 255., 255.],
#          [255., 255., 255., 255.],
#          [255., 255., 255., 255.],
#          ...,
#          [255., 255., 255., 255.],
#          [255., 255., 255., 255.],
#          [255., 255., 255., 255.]],
#
#         ...,
#
#         [[255., 255., 255., 255.],
#          [255., 255., 255., 255.],
#          [255., 255., 255., 255.],
#          ...,
#          [255., 255., 255., 255.],
#          [255., 255., 255., 255.],
# ...

# %%
import scipy

# %%
smiley = Image.open('imgs/drone.png')
print(smiley.mode)
# Out:
# P
